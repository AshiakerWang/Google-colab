# %% [markdown]
# <a href="https://colab.research.google.com/github/AshiakerWang/Google-colab/blob/master/mnist_dpsgd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# !git clone https://github.com/tensorflow/privacy.git
# Out:
# Cloning into 'privacy'...
# remote: Enumerating objects: 243, done.
# remote: Counting objects: 100% (243/243), done.
# remote: Compressing objects: 100% (200/200), done.
# remote: Total 1743 (delta 135), reused 129 (delta 43), pack-reused 1500
# Receiving objects: 100% (1743/1743), 657.52 KiB | 1.88 MiB/s, done.
# Resolving deltas: 100% (1163/1163), done.

# %%
# !python3 mnist_dpsgd_tutorial.py --learning_rate 0.25 --noise_multiplier 1.3 --l2_norm_clip 1.5 --batch_size 256 --epochs 15 --num_microbatches 256
# Out:
# 2020-05-27 00:58:18.869335: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "mnist_dpsgd_tutorial.py", line 29, in <module>
#     from tensorflow_privacy.privacy.analysis import compute_dp_sgd_privacy_lib
# ImportError: cannot import name 'compute_dp_sgd_privacy_lib'

# %%
# !unzip -o privacy.zip
# Out:
# Archive:  privacy.zip
#    creating: .git/
#   inflating: .git/config
#   inflating: .git/description
#   inflating: .git/HEAD
#    creating: .git/hooks/
#   inflating: .git/hooks/applypatch-msg.sample
#   inflating: .git/hooks/commit-msg.sample
#   inflating: .git/hooks/fsmonitor-watchman.sample
#   inflating: .git/hooks/post-update.sample
#   inflating: .git/hooks/pre-applypatch.sample
#   inflating: .git/hooks/pre-commit.sample
#   inflating: .git/hooks/pre-merge-commit.sample
#   inflating: .git/hooks/pre-push.sample
#   inflating: .git/hooks/pre-rebase.sample
#   inflating: .git/hooks/pre-receive.sample
#   inflating: .git/hooks/prepare-commit-msg.sample
#   inflating: .git/hooks/update.sample
#   inflating: .git/index
#    creating: .git/info/
#   inflating: .git/info/exclude
#    creating: .git/logs/
#   inflating: .git/logs/HEAD
#    creating: .git/logs/refs/
#    creating: .git/logs/refs/heads/
#   inflating: .git/logs/refs/heads/master
# ...

# %%
# !python3 mnist_dpsgd_tutorial.py --learning_rate 0.25 --noise_multiplier 1.3 --l2_norm_clip 1.5 --batch_size 256 --epochs 15 --microbatches 256
# Out:
# 2020-05-27 01:47:12.556225: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-27 01:47:14.578032: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-27 01:47:14.582456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-27 01:47:14.583075: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-05-27 01:47:14.583116: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...
